# %% [markdown]
# ## What is Serialization & Deserialization?
# |Term	         |Meaning	                             | Python Function |
# |--------------- |---------------------------------------|-----------------|
# |Serialization	 |Python Object → String (JSON Format)	 | json.dumps()    |
# |Deserialization |JSON String → Python Object	         | json.loads()    |

# %% [markdown]
# ### Why JSON is Important?
# read() → Always gives string
#
# To store Numbers / Lists / Dictionaries → Use json module
#
# JSON is universal — works in APIs, Web, Mobile, Cloud

# %%
import json 

ls = [1,'2','lalit']

with open('data.json', 'w+', encoding = 'utf-8') as f:
    # f.write(json.dumps(ls))
    json.dump(ls,f)
    f.seek(0)
    print(json.load(f))
# Out:
# [1, '2', 'lalit']

# %%
employee = [
    {"name": "Lalit", "role": "Data Engineer"},
    {"name": "Aditya", "role": "Data Scientist"},
    {"name": "Tushar", "role": "Backend Developer"}
]

# %%
with open('config.json', 'w', encoding = 'utf-8') as f:
    json.dump(employee,f,indent = 4)

# %%
with open('config.json', 'r',encoding = 'utf-8') as f:
    data = json.load(f)

for row in data:
    print(row['name'])
# Out:
# Lalit
# Aditya
# Tushar

# %%
import requests

data = requests.get("https://jsonplaceholder.typicode.com/users").json()

# %%
print([[x['name'],x['email']] for x in data])
# Out:
# [['Leanne Graham', 'Sincere@april.biz'], ['Ervin Howell', 'Shanna@melissa.tv'], ['Clementine Bauch', 'Nathan@yesenia.net'], ['Patricia Lebsack', 'Julianne.OConner@kory.org'], ['Chelsey Dietrich', 'Lucio_Hettinger@annie.ca'], ['Mrs. Dennis Schulist', 'Karley_Dach@jasper.info'], ['Kurtis Weissnat', 'Telly.Hoeger@billy.biz'], ['Nicholas Runolfsdottir V', 'Sherwood@rosamond.me'], ['Glenna Reichert', 'Chaim_McDermott@dana.io'], ['Clementina DuBuque', 'Rey.Padberg@karina.biz']]

# %% [markdown]
# ### Hardest — Flatten Nested JSON Data

# %%
data = {
    "user": {
        "name": "Lalit",
        "address": {
            "city": "Indore",
            "state": "MP"
        }
    }
}

# %%
def flatten_nested_json(d, parentkey = ''):
    item = []
    for k,v in data.items():
        print(k,v)
        if isinstance(v,dict):
            flatten_nested_json(v)
    return 0

flatten_json = flatten_nested_json(data)
# Out:
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# ...
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# user {'name': 'Lalit', 'address': {'city': 'Indore', 'state': 'MP'}}
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[40], line 9
#       6             flatten_nested_json(v)
#       7     return 0
# ----> 9 flatten_json = flatten_nested_json(data)
#
# Cell In[40], line 6, in flatten_nested_json(d, parentkey)
#       4     print(k,v)
#       5     if isinstance(v,dict):
# ----> 6         flatten_nested_json(v)
#       7 return 0
#
# Cell In[40], line 6, in flatten_nested_json(d, parentkey)
#       4     print(k,v)
#       5     if isinstance(v,dict):
# ----> 6         flatten_nested_json(v)
#       7 return 0
#
#     [... skipping similar frames: flatten_nested_json at line 6 (2972 times)]
#
# Cell In[40], line 6, in flatten_nested_json(d, parentkey)
#       4     print(k,v)
#       5     if isinstance(v,dict):
# ----> 6         flatten_nested_json(v)
#       7 return 0
#
# Cell In[40], line 4, in flatten_nested_json(d, parentkey)
#       2 item = []
#       3 for k,v in data.items():
# ----> 4     print(k,v)
#       5     if isinstance(v,dict):
#       6         flatten_nested_json(v)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\iostream.py:664, in OutStream.write(self, string)
#     655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)
#     662
#     663     """
# --> 664     parent = self.parent_header
#     666     if not isinstance(string, str):
#     667         msg = f"write() argument must be str, not {type(string)}"  # type:ignore[unreachable]
#
# RecursionError: maximum recursion depth exceeded
